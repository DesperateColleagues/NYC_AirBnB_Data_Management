# %%
import pandas as pd

# %%
df = pd.read_csv("../../datasets/csv_datasets/subway_stops.csv")

# %%
df.head()
# Out:
#   stop_id  stop_code                    stop_name  stop_desc   stop_lat  \
# 0     101        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 1    101N        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 2    101S        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 3     103        NaN                       238 St        NaN  40.884667
# 4    103N        NaN                       238 St        NaN  40.884667
#
#     stop_lon  zone_id  stop_url  location_type parent_station
# 0 -73.898583      NaN       NaN              1            NaN
# 1 -73.898583      NaN       NaN              0            101
# 2 -73.898583      NaN       NaN              0            101
# 3 -73.900870      NaN       NaN              1            NaN
# 4 -73.900870      NaN       NaN              0            103

# %%
df.groupby(["stop_name", "stop_lat", "stop_lon"])[["location_type"]].size()
# Out:
# stop_name              stop_lat   stop_lon
# 1 Av                   40.730953  -73.981628    3
# 103 St                 40.790600  -73.947478    3
#                        40.796092  -73.961454    3
#                        40.799446  -73.968379    3
# 103 St - Corona Plaza  40.749865  -73.862700    3
#                                                ..
# Woodlawn               40.886037  -73.878751    3
# Woodside - 61 St       40.745630  -73.902984    3
# World Trade Center     40.712582  -74.009781    3
# York St                40.701397  -73.986751    3
# Zerega Av              40.836488  -73.847036    3
# Length: 498, dtype: int64

# %%
df.loc[df["stop_name"] == "103 St"]
# Out:
#     stop_id  stop_code stop_name  stop_desc   stop_lat   stop_lon  zone_id  \
# 48      119        NaN    103 St        NaN  40.799446 -73.968379      NaN
# 49     119N        NaN    103 St        NaN  40.799446 -73.968379      NaN
# 50     119S        NaN    103 St        NaN  40.799446 -73.968379      NaN
# 414     624        NaN    103 St        NaN  40.790600 -73.947478      NaN
# 415    624N        NaN    103 St        NaN  40.790600 -73.947478      NaN
# 416    624S        NaN    103 St        NaN  40.790600 -73.947478      NaN
# 576     A18        NaN    103 St        NaN  40.796092 -73.961454      NaN
# 577    A18N        NaN    103 St        NaN  40.796092 -73.961454      NaN
# 578    A18S        NaN    103 St        NaN  40.796092 -73.961454      NaN
#
#      stop_url  location_type parent_station
# 48        NaN              1            NaN
# 49        NaN              0            119
# 50        NaN              0            119
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stop_id         1503 non-null   object
#  1   stop_code       0 non-null      float64
#  2   stop_name       1503 non-null   object
#  3   stop_desc       0 non-null      float64
#  4   stop_lat        1503 non-null   float64
#  5   stop_lon        1503 non-null   float64
#  6   zone_id         0 non-null      float64
#  7   stop_url        0 non-null      float64
#  8   location_type   1503 non-null   int64
#  9   parent_station  1002 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 117.5+ KB

# %%
from geopy.geocoders import Nominatim

loc = Nominatim(user_agent='http')

getLoc = loc.geocode('4453 PARK AVENUE NYC')
print(getLoc.latitude)
# Out:
# 40.8539694
